# %% [markdown]
# NAME - KUSHAGRA RAJ
# ID -  202318048

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
def get_element_text(soup, tag, attrs):
    try:
        element = soup.find(tag, attrs=attrs).string.strip()
    except AttributeError:
        element = ""
    return element

# %%
def get_title(soup):
    try:
        title = soup.find("span", attrs={"id": 'productTitle'})
        title_value = title.text
        title_string = title_value.strip()
    except AttributeError as e:
        title_string = f"Error: {e}"
    return title_string

# %%
def get_review_count(soup):
    return get_element_text(soup, "span", {'id': 'acrCustomerReviewText'})

# %%
def get_rating(soup):
    return get_element_text(soup, "i", {'class': 'a-icon a-icon-star a-star-4-5'}) or get_element_text(soup, "span", {'class': 'a-icon-alt'})

# %%
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id': 'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = "Not Available"
    return available

# %%
def get_price(soup):
    price_element = soup.find("span", attrs={"class": "a-price-whole"})
    if price_element:
        price = price_element.text
        return price
    else:
        return None

# %%
if __name__ == '__main__':
    HEADERS = {'User-Agent': '', 'Accept-Language': 'en-US, en;q=0.5'}

    URL = 'https://www.amazon.in/s?k=self+help&ref=nb_sb_noss_1'
    webpage = requests.get(URL, headers=HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")

    links = soup.find_all("a", attrs={'class': 'a-link-normal s-no-outline'})
    links_list = [link.get('href') for link in links]

    data_list = []

    for link in links_list:
        new_webpage = requests.get("https://www.amazon.in" + link, headers=HEADERS)
        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        data_list.append({
            'title': get_title(new_soup),
            'price': get_price(new_soup),
            'rating': get_rating(new_soup),
            'reviews': get_review_count(new_soup),
            'availability': get_availability(new_soup)
        })

    df = pd.DataFrame(data_list)

# %%
df
# Out:
#                                                 title price  \
# 0   The Greatest Self-Help Book (is the one writte...  519.
# 1   Pack of 3 Self Help Bookset for Adult - How to...   299
# 2   Do It Today: Overcome procrastination, improve...  134.
# 3   Pack of 6 Self Help Book for Adult - How to Se...   539
# 4   Dale Carnegie’s How to Win Friends and Influen...   89.
# 5   Think Straight: Change your thoughts, Change y...  150.
# 6   Learn, Don't Study: A guide for students and p...   246
# 7   The NO-BS Self-Help Book: The No-Fluff Guide t...   99.
# 8   THE ART OF THINKING CLEARLY: BETTER THINKING, ...  370.
# 9   The Power of Your Subconscious Mind (GP Self-H...   94.
# 10  MINDFUL ZEN HABITS: From Suffering to Happines...  196.
# 11                                      Atomic Habits  469.
# 12  Deep Work: Rules for Focused Success in a Dist...  325.
# 13  The Power of Awareness: Neville Goddard's Popu...   80.
# 14  The Art of Avoiding People: Hacks and Habits f...  149.
# 15  The Korean Book of Happiness: Joy, resilience ...   402
#
#                 rating         reviews   availability
# 0   4.5 out of 5 stars     613 ratings       In stock
# 1   4.4 out of 5 stars      64 ratings       In stock
# 2   4.4 out of 5 stars   8,449 ratings       In stock
# 3   4.4 out of 5 stars     105 ratings       In stock
# 4   4.4 out of 5 stars     566 ratings       In stock
# 5   4.2 out of 5 stars  13,007 ratings       In stock
# 6   4.4 out of 5 stars      38 ratings       In stock
# 7   4.2 out of 5 stars      62 ratings  Not Available
# 8   4.5 out of 5 stars   5,164 ratings       In stock
# 9   4.5 out of 5 stars  80,771 ratings  Not Available
# 10  4.4 out of 5 stars     508 ratings       In stock
# 11  4.6 out of 5 stars  89,226 ratings       In stock
# 12  4.5 out of 5 stars  27,641 ratings
# 13  4.6 out of 5 stars   3,808 ratings  Not Available
# 14  5.0 out of 5 stars       2 ratings  Not Available
# 15  4.6 out of 5 stars      22 ratings       In stock
