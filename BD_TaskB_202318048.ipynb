# %%
import requests
import csv

url = "https://real-time-amazon-data.p.rapidapi.com/search"

querystring = {"query": "watch", "page": "1", "country": "US", "category_id": "aps"}

headers = {
    "X-RapidAPI-Key": "5fde53e60dmshee72ae95caecfb4p1ab381jsn408b9da1ff62",
    "X-RapidAPI-Host": "real-time-amazon-data.p.rapidapi.com",
}

response = requests.get(url, headers=headers, params=querystring)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    data = response.json().get("data", {})  # Extract data from the response

    # Check if the data contains product information
    if "products" in data:
        products = data["products"]

        # Extract headers and rows from the product data
        headers = products[0].keys() if products else []
        rows = [product.values() for product in products] if products else []

        # Create a CSV file
        csv_file_path = 'amazon_products.csv'
        with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
            # Create a CSV writer
            csv_writer = csv.writer(csv_file)

            # Write headers
            csv_writer.writerow(headers)

            # Write rows
            csv_writer.writerows(rows)

        print(f'Data successfully converted and saved to {csv_file_path}')

    else:
        print("No product information found in the API response.")
else:
    print(f"Failed to retrieve data. Status Code: {response.status_code}")
    print(response.text)
# Out:
# Data successfully converted and saved to amazon_products.csv

# %%
import pandas as pd
df = pd.read_csv('/content/amazon_products.csv')
df
# Out:
#           asin                                      product_title  \
# 0   B000GAWSDG  Casio F91W-1 Classic Resin Strap Digital Sport...
# 1   B0194LW5BM       Timex Men&#x27;s Expedition Scout 40mm Watch
# 2   B07K77NTDZ  LYMFHCH Men&#x27;s Digital Watch, Sports Water...
# 3   B00Y2S944E  Armitron Sport Women&#x27;s 45/7012 Digital Ch...
# 4   B09N8VTCSY  LIVIKEY LIVIKEY Smart Watch, Fitness Tracker w...
# 5   B0C2TF41Z2  LN LENQIN Mens Watches Analog Quartz Sports Un...
# 6   B0CG1P8RN3  Nerunsa Smart Watch(Answer/Make Call), 1.85&qu...
# 7   B07L1GRYN4  TOZO S4 AcuFit One Smart Watch 1.78&quot; AMOL...
# 8   B075YYK9NL  Nine West Women&#x27;s Crystal Accented Bracel...
# 9   B000GB0G7A  Casio Men&#x27;s MQ24-7B2 Analog Watch with Bl...
# 10  B0053HBJBE  Casio Unisex F-108WH-1ACF Big Square Digital D...
# 11  B000AYYIYU                 Timex Men&#x27;s Easy Reader Watch
# 12  B0CH2SCLZL  Nerunsa Smart Watch (Answer/Make Calls), 1.85&...
# 13  B004AOLA1A  Casio Men&#x27;s FT-500WC-5BVCF Forester Sport...
# 14  B01DQDE3RI  Aposon LYMFHCH Men&#x27;s Digital Sports Watch...
# 15  B004X4Y9ME        Anne Klein Women&#x27;s Leather Strap Watch
# 16  B08DKYLK4D  Amazfit Amazfit Band 5 Activity Fitness Tracke...
# 17  B000AYW0KO               Timex Women&#x27;s Easy Reader Watch
# 18  B0CH39KRJF  Singerdeer Smart Watch (Answer/Make Call) Blue...
# 19  B006ZTJEPC  Armitron Sport Unisex Digital Chronograph Nylo...
#
#    product_price product_original_price currency  product_star_rating  \
# 0         $15.26                 $22.95      USD                  4.6
# 1         $39.20                 $62.00      USD                  4.4
# 2         $15.27                 $39.99      USD                  4.5
# 3         $13.00                 $18.75      USD                  4.2
# 4         $16.99                 $21.99      USD                  4.1
# 5          $9.99                    NaN      USD                  4.2
# 6         $29.99                 $79.99      USD                  4.1
# 7         $49.99                 $59.99      USD                  4.7
# 8         $17.64                 $36.75      USD                  4.5
# 9         $16.00                 $22.95      USD                  4.4
# 10        $16.88                 $22.95      USD                  4.6
# 11        $32.90                 $50.00      USD                  4.5
# 12        $29.99                 $89.99      USD                  4.1
# 13        $21.92                 $35.95      USD                  4.5
# 14        $14.99                 $24.99      USD                  3.9
# 15        $23.14                 $55.00      USD                  4.5
# 16        $35.73                 $39.99      USD                  4.0
# 17        $42.41                 $62.00      USD                  4.5
# 18        $19.99                 $93.99      USD                  4.0
# 19        $14.99                 $18.75      USD                  4.5
#
#     product_num_ratings                           product_url  \
# 0                 49623  https://www.amazon.com/dp/B000GAWSDG
# 1                 21796  https://www.amazon.com/dp/B0194LW5BM
# 2                  2308  https://www.amazon.com/dp/B07K77NTDZ
# 3                 17315  https://www.amazon.com/dp/B00Y2S944E
# 4                  1793  https://www.amazon.com/dp/B09N8VTCSY
# 5                   812  https://www.amazon.com/dp/B0C2TF41Z2
# 6                  7402  https://www.amazon.com/dp/B0CG1P8RN3
# 7                   283  https://www.amazon.com/dp/B07L1GRYN4
# 8                  8649  https://www.amazon.com/dp/B075YYK9NL
# 9                  7677  https://www.amazon.com/dp/B000GB0G7A
# 10                20509  https://www.amazon.com/dp/B0053HBJBE
# 11                47959  https://www.amazon.com/dp/B000AYYIYU
# 12                11100  https://www.amazon.com/dp/B0CH2SCLZL
# 13                 6611  https://www.amazon.com/dp/B004AOLA1A
# 14                 4618  https://www.amazon.com/dp/B01DQDE3RI
# 15                 7350  https://www.amazon.com/dp/B004X4Y9ME
# 16                29529  https://www.amazon.com/dp/B08DKYLK4D
# 17                50666  https://www.amazon.com/dp/B000AYW0KO
# 18                   96  https://www.amazon.com/dp/B0CH39KRJF
# 19                 3412  https://www.amazon.com/dp/B006ZTJEPC
#
#                                         product_photo  product_num_offers  \
# 0   https://m.media-amazon.com/images/I/51Nk5SEBAR...                 NaN
# 1   https://m.media-amazon.com/images/I/71spWNT8LE...                 NaN
# 2   https://m.media-amazon.com/images/I/61AepCrYDO...                 NaN
# 3   https://m.media-amazon.com/images/I/71j0nFQ4Nq...                 NaN
# 4   https://m.media-amazon.com/images/I/61YlcspFd2...                 NaN
# 5   https://m.media-amazon.com/images/I/71FH0+qBs1...                 NaN
# 6   https://m.media-amazon.com/images/I/71VSFdowcu...                 NaN
# 7   https://m.media-amazon.com/images/I/71Yme8YJAY...                 NaN
# 8   https://m.media-amazon.com/images/I/81-HbGIsxV...                 NaN
# 9   https://m.media-amazon.com/images/I/516s1Ljzp6...                 NaN
# 10  https://m.media-amazon.com/images/I/510T962DtN...                 NaN
# 11  https://m.media-amazon.com/images/I/71S-CCwawq...                 NaN
# 12  https://m.media-amazon.com/images/I/71odmY7Qc2...                 NaN
# 13  https://m.media-amazon.com/images/I/91AgG0TMbD...                 NaN
# 14  https://m.media-amazon.com/images/I/61xLsU9PzH...                 NaN
# 15  https://m.media-amazon.com/images/I/81PrmvhOIV...                 NaN
# 16  https://m.media-amazon.com/images/I/51ja6ds+pM...                 NaN
# 17  https://m.media-amazon.com/images/I/61FBDjR19G...                 NaN
# 18  https://m.media-amazon.com/images/I/71714YtPXO...                 NaN
# 19  https://m.media-amazon.com/images/I/81dVjlmIgU...                 NaN
#
#    product_minimum_offer_price  is_best_seller  is_amazon_choice  is_prime  \
# 0                       $15.26            True             False      True
# 1                       $39.20           False              True      True
# 2                       $15.27           False             False      True
# 3                       $13.00           False             False      True
# 4                       $16.99           False             False      True
# 5                        $9.99           False             False      True
# 6                       $29.99           False             False      True
# 7                       $49.99           False             False      True
# 8                       $17.64           False             False      True
# 9                       $16.00           False             False      True
# 10                      $16.88           False             False      True
# 11                      $32.90           False             False      True
# 12                      $29.99           False             False      True
# 13                      $21.92           False             False      True
# 14                      $14.99           False             False      True
# 15                      $23.14           False             False      True
# 16                      $35.73           False             False      True
# 17                      $42.41            True             False      True
# 18                      $19.99           False             False      True
# 19                      $14.99           False             False      True
#
#     climate_pledge_friendly               sales_volume  \
# 0                     False   7K+ bought in past month
# 1                     False   1K+ bought in past month
# 2                     False   1K+ bought in past month
# 3                     False  800+ bought in past month
# 4                     False  500+ bought in past month
# 5                     False   1K+ bought in past month
# 6                     False   1K+ bought in past month
# 7                     False   1K+ bought in past month
# 8                     False   3K+ bought in past month
# 9                     False   1K+ bought in past month
# 10                    False   2K+ bought in past month
# 11                    False   1K+ bought in past month
# 12                    False   3K+ bought in past month
# 13                    False   1K+ bought in past month
# 14                    False  100+ bought in past month
# 15                    False   1K+ bought in past month
# 16                    False   3K+ bought in past month
# 17                    False  700+ bought in past month
# 18                    False  200+ bought in past month
# 19                    False  500+ bought in past month
#
#                                              delivery
# 0   FREE delivery Mon, Feb 5 on $35 of items shipp...
# 1   FREE delivery Mon, Feb 5 Or fastest delivery T...
# 2   FREE delivery Mon, Feb 5 on $35 of items shipp...
# 3   FREE delivery Mon, Feb 5 on $35 of items shipp...
# 4   FREE delivery Mon, Feb 5 on $35 of items shipp...
# 5   FREE delivery Mon, Feb 5 on $35 of items shipp...
# 6   FREE delivery Mon, Feb 5 on $35 of items shipp...
# 7   FREE delivery Mon, Feb 5 Or fastest delivery T...
# 8   FREE delivery Mon, Feb 5 on $35 of items shipp...
# 9   FREE delivery Mon, Feb 5 on $35 of items shipp...
# 10  FREE delivery Mon, Feb 5 on $35 of items shipp...
# 11  FREE delivery Mon, Feb 5 on $35 of items shipp...
# 12  FREE delivery Mon, Feb 5 on $35 of items shipp...
# 13  FREE delivery Mon, Feb 5 on $35 of items shipp...
# 14  FREE delivery Mon, Feb 5 on $35 of items shipp...
# 15  FREE delivery Mon, Feb 5 on $35 of items shipp...
# 16  FREE delivery Mon, Feb 5 Or fastest delivery T...
# 17  FREE delivery Mon, Feb 5 Or fastest delivery T...
# 18  FREE delivery Mon, Feb 5 on $35 of items shipp...
# 19  FREE delivery Mon, Feb 5 on $35 of items shipp...
